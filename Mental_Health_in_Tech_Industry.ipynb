# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/car_price_prediction.csv')
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
df.shape
# Out:
# (19237, 18)

# %%
df.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Mental Health in Tech Industry.csv')
df
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0     27-08-2014 11:29   37  Female   United States    IL           NaN
# 1     27-08-2014 11:29   44       M   United States    IN           NaN
# 2     27-08-2014 11:29   32    Male          Canada   NaN           NaN
# 3     27-08-2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4     27-08-2014 11:30   31    Male   United States    TX           NaN
# ...                ...  ...     ...             ...   ...           ...
# 1254  12-09-2015 11:17   26    male  United Kingdom   NaN            No
# 1255  26-09-2015 01:07   32    Male   United States    IL            No
# 1256  07-11-2015 12:36   34    male   United States    CA            No
# 1257  30-11-2015 21:25   46       f   United States    NC            No
# 1258  01-02-2016 23:04   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
df.head(10)
# Out:
#           Timestamp  Age  Gender         Country state self_employed  \
# 0  27-08-2014 11:29   37  Female   United States    IL           NaN
# 1  27-08-2014 11:29   44       M   United States    IN           NaN
# 2  27-08-2014 11:29   32    Male          Canada   NaN           NaN
# 3  27-08-2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4  27-08-2014 11:30   31    Male   United States    TX           NaN
# 5  27-08-2014 11:31   33    Male   United States    TN           NaN
# 6  27-08-2014 11:31   35  Female   United States    MI           NaN
# 7  27-08-2014 11:32   39       M          Canada   NaN           NaN
# 8  27-08-2014 11:32   42  Female   United States    IL           NaN
# 9  27-08-2014 11:32   23    Male          Canada   NaN           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often          Jun-25  ...
# 1             No        No         Rarely  More than 1000  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
##Gender Distribution
sns.countplot(data=df_cleaned, x='Gender')
plt.title("Gender Distribution")
plt.show()

# %%
## Age Distribution
sns.histplot(data=df_cleaned, x='Age', bins=20, kde=True)
plt.title("Age Distribution")
plt.show()

# %%
##Treatment vs No Treatment
sns.countplot(data=df_cleaned, x='treatment', hue='Gender')
plt.title("Treatment by Gender")
plt.show()

# %%
##Mental Health Interference at Work

sns.countplot(data=df_cleaned, x='work_interfere', order=df_cleaned['work_interfere'].value_counts().index)
plt.title("Mental Health Interference at Work")
plt.xticks(rotation=45)
plt.show()

# %%
##What are the top 5 countries with the most respondents?

df_cleaned['Country'].value_counts().head(5)
# Out:
# Country
# United States     746
# United Kingdom    184
# Canada             72
# Germany            45
# Netherlands        27
# Name: count, dtype: int64

# %%
##What percentage of respondents have a family history of mental illness?

family_history_counts = df_cleaned['family_history'].value_counts(normalize=True) * 100
print(family_history_counts)
# Out:
# family_history
# No     60.911271
# Yes    39.088729
# Name: proportion, dtype: float64

# %%
##How many people are self-employed?

df_cleaned['self_employed'].value_counts()
# Out:
# self_employed
# No     1091
# Yes     142
# Name: count, dtype: int64

# %%
##What is the average age of respondents who have received treatment?

treated_avg_age = df_cleaned[df_cleaned['treatment'] == 'Yes']['Age'].mean()
print(f"Average age of treated respondents: {treated_avg_age:.2f}")
# Out:
# Average age of treated respondents: 32.61

# %%
## What is the gender distribution among those who have not received treatment?

df_cleaned[df_cleaned['treatment'] == 'No']['Gender'].value_counts()
# Out:
# Gender
# Male     500
# Other    119
# Name: count, dtype: int64

# %%
##What is the distribution of the number of employees in the companies respondents work for?

df_cleaned['no_employees'].value_counts()
# Out:
# no_employees
# Jun-25            289
# 26-100            288
# More than 1000    281
# 100-500           175
# 01-May            158
# 500-1000           60
# Name: count, dtype: int64

# %%
##How many respondents feel their mental health interferes "Often" with their work?

df_cleaned[df_cleaned['work_interfere'] == 'Often'].shape[0]
# Out:
# 140

# %%
##How many people think mental health is taken as seriously as physical health at their workplace?

df_cleaned['mental_vs_physical'].value_counts()
# Out:
# mental_vs_physical
# Don't know    574
# Yes           339
# No            338
# Name: count, dtype: int64
